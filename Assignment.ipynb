# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Daniel Baltar**
#
# Data Scientist

# %% [markdown]
# *I am interested in Data Science because I am curious and like information.*

# %% [markdown]
# ### My code is supposed to find out what is five to the power of four to the power of three

# %%
5**4**3
# Out:
# 542101086242752217003726400434970855712890625

# %% [markdown]
# 1. This is the first item
# 2. This is the second item
#
# - This is a first bullet
# - This is the second bullet
#
# This is a random image:
# ![Christmas-coloring-pages-printable-winter-download-free-for-kids-art-sheet-to-color-42.jpg](attachment:Christmas-coloring-pages-printable-winter-download-free-for-kids-art-sheet-to-color-42.jpg)
